-- %%
-- 1. Fetch all customers from India.
select * from customers where country = 'India'

-- 2. List all products with price greater than 1000.
select * from product where price > 100

-- 3. Display all orders placed in 2024.
select * from orders where year == 2024

-- 4.Show top 10 most recent orders.
select * from orders order by order_date desc limit 10

-- 5.Find all orders where order_status = 'Cancelled'.
select count(*) from orders where order_status = 'CANCELLED'
