-- %%
SELECT first_name, country
FROM (
    SELECT first_name,
           country,
           dense_rank() OVER (PARTITION BY country ORDER BY city) AS ranknum
    FROM customers
) 
WHERE ranknum = 2;
