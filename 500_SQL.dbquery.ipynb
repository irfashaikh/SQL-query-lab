-- %%
-- Find customers who placed orders above the average order amount.



-- Find customers who placed orders on the same day they signed up.


select customers.signup_date , orders.order_date from customers
join orders 
on customers.customer_id = orders.customer_id
where customers.signup_date = orders.order_date
